# %% [markdown]
# # No_balancing Method
#
# This notebook will apply the no_balancing balancing method to the training data.

# %%
import pandas as pd

train_df = pd.read_csv('train.csv')
val_df = pd.read_csv('val.csv')

print(f"Training Set Size: {len(train_df)} instances")
print(f"Validation Set Size: {len(val_df)} instances")
# Out:
# Training Set Size: 151875 instances
# Validation Set Size: 50626 instances

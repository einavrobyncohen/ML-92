# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sb

# %% [markdown]
# - 0 = no diabetes
# - 1 = prediabetes
# - 2 = diabetes

# %%
# Read the csv and store in variable diabetes_data
diabetes_data = pd.read_csv("diabetes_multiclass.csv") 
# Filter the data based on the diabetes categories (no diabetes, prediabetic, diabetes)
diabetes_0 = diabetes_data[diabetes_data['Diabetes_012'] == 0]
diabetes_1 = diabetes_data[diabetes_data['Diabetes_012'] == 1]
diabetes_2 = diabetes_data[diabetes_data['Diabetes_012'] == 2]

# %% [markdown]
# # Features: Diabetes_012 vs Education
# Education level (EDUCA see codebook) scale 1-6
# - 1 = Never attended school or only kindergarten
# - 2 = Grades 1 through 8 (Elementary)
# - 3 = Grades 9 through 11 (Some high school)
# - 4 = Grade 12 or GED (High school graduate)
# - 5 = College 1 year to 3 years (Some college or technical school)
# - 6 = College 4 years or more (College graduate)

# %%
# Count occurrences of each education level wrt diabetes levels and sort from 1 to 6
education0_counts = diabetes_0['Education'].value_counts().sort_index()
education1_counts = diabetes_1['Education'].value_counts().sort_index()
education2_counts = diabetes_2['Education'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(6)
plt.bar(x, education0_counts, width = 0.2, color='plum', label='non diabetic')
plt.bar(x+0.2, education1_counts, width = 0.2, color='salmon', label='pre-diabetic')
plt.bar(x-0.2, education2_counts, width = 0.2, color='lightskyblue', label='diabetic')

# Labels + title
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.title('Frequency of Education Levels for Diabetes_012')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each education level wrt non diabetes and sort from 1 to 6
education0_counts = diabetes_0['Education'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(6)
plt.bar(x, education0_counts, width = 0.2, color='plum', label='non diabetic')

# Labels + title
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.title('Frequency of Education Levels for Non Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each education level wrt pre diabetic and sort from 1 to 6
education1_counts = diabetes_1['Education'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(6)
plt.bar(x, education1_counts, width = 0.2, color='salmon', label='pre-diabetic')

# Labels + title
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.title('Frequency of Education Levels for Pre-Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each education level wrt diabetes and sort from 1 to 6
education2_counts = diabetes_2['Education'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(6)
plt.bar(x, education2_counts, width = 0.2, color='lightskyblue', label='diabetic')

# Labels + title
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.title('Frequency of Education Levels for Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# # Features: Diabetes_012 vs Income
# Income scale (INCOME2 see codebook) scale 1-8
# - 1 = less than $10,000
# - 5 = less than $35,000
# - 8 = $75,000 or more

# %%
# Count occurrences of each income level wrt diabetes categories and sort from 1 to 8
income0_counts = diabetes_0['Income'].value_counts().sort_index()
income1_counts = diabetes_1['Income'].value_counts().sort_index()
income2_counts = diabetes_2['Income'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(8)
plt.bar(x, income0_counts, width = 0.2, color='aquamarine', label='non diabetic')
plt.bar(x+0.2, income1_counts, width = 0.2, color='violet', label='pre-diabetic')
plt.bar(x-0.2, income2_counts, width = 0.2, color='gold', label='diabetic')

# Labels + title
plt.xlabel('Income Level')
plt.ylabel('Frequency')
plt.title('Frequency of Income Levels for Diabetes_012')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each income level wrt non diabetic and sort from 1 to 8
income0_counts = diabetes_0['Income'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(8)
plt.bar(x, income0_counts, width = 0.2, color='aquamarine', label='non diabetic')

# Labels + title
plt.xlabel('Income Level')
plt.ylabel('Frequency')
plt.title('Frequency of Income Levels for Non Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each income level wrt pre diabetic and sort from 1 to 8
income1_counts = diabetes_1['Income'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(8)
plt.bar(x, income1_counts, width = 0.2, color='violet', label='pre-diabetic')

# Labels + title
plt.xlabel('Income Level')
plt.ylabel('Frequency')
plt.title('Frequency of Income Levels for Pre-Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of each education level wrt diabetes and sort from 1 to 8
income1_counts = diabetes_1['Income'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = 1 + np.arange(8)
plt.bar(x, income1_counts, width = 0.2, color='gold', label='diabetic')

# Labels + title
plt.xlabel('Income Level')
plt.ylabel('Frequency')
plt.title('Frequency of Income Levels for Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# # Features: Diabetes_012 vs AnyHealthCare
# Have any kind of health care coverage, including health insurance, prepaid plans such as HMO, etc.
# - 0 = no
# - 1 = yes
#
# * Note: will have to change the x-axis!

# %%
# Count occurrences of healthcare and no-healthcare wrt diabetes categories and sort from 1 to 2
healthcare0_counts = diabetes_0['AnyHealthcare'].value_counts().sort_index()
healthcare1_counts = diabetes_1['AnyHealthcare'].value_counts().sort_index()
healthcare2_counts = diabetes_2['AnyHealthcare'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = np.arange(2)
plt.bar(['false','true'], healthcare0_counts, width = 0.2, color='lightcoral', label='non diabetic')
plt.bar(x+0.2, healthcare1_counts, width = 0.2, color='springgreen', label='pre-diabetic')
plt.bar(x-0.2, healthcare2_counts, width = 0.2, color='dodgerblue', label='diabetic')

# Labels + title
plt.xlabel('AnyHealthcare')
plt.ylabel('Frequency')
plt.title('Frequency of AnyHealthcare for Diabetes_012')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of healthcare and no-healthcare wrt non diabetic and sort from 1 to 2
healthcare0_counts = diabetes_0['AnyHealthcare'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
plt.bar(['false','true'], healthcare0_counts, width = 0.2, color='lightcoral', label='non diabetic')

# Labels + title
plt.xlabel('AnyHealthcare')
plt.ylabel('Frequency')
plt.title('Frequency of AnyHealthcare for Non Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of healthcare and no-healthcare wrt pre-diabetes and sort from 1 to 2
healthcare1_counts = diabetes_1['AnyHealthcare'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
plt.bar(['false','true'], healthcare1_counts, width = 0.2, color='springgreen', label='pre-diabetic')

# Labels + title
plt.xlabel('AnyHealthcare')
plt.ylabel('Frequency')
plt.title('Frequency of AnyHealthcare for Pre-Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of healthcare and no-healthcare wrt diabetes and sort from 1 to 2
healthcare2_counts = diabetes_2['AnyHealthcare'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
plt.bar(['false','true'], healthcare2_counts, width = 0.2, color='dodgerblue', label='diabetic')

# Labels + title
plt.xlabel('AnyHealthcare')
plt.ylabel('Frequency')
plt.title('Frequency of AnyHealthcare for Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# # Features: Diabetes_012 vs NoDocbcCost
# Was there a time in the past 12 months when you needed to see a doctor but could not because of cost?
# - 0 = no
# - 1 = yes
# * Note: will have to change the x-axis!

# %%
# Count occurrences of no-doctor-cost being true and false wrt diabetes categories
docCost0_count = diabetes_0['NoDocbcCost'].value_counts().sort_index()
docCost1_count = diabetes_1['NoDocbcCost'].value_counts().sort_index()
docCost2_count = diabetes_2['NoDocbcCost'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = np.arange(2)
plt.bar(['false','true'], docCost0_count, width = 0.2, color='slateblue', label='non diabetic')
plt.bar(x+0.2, docCost1_count, width = 0.2, color='firebrick', label='pre-diabetic')
plt.bar(x-0.2, docCost2_count, width = 0.2, color='seagreen', label='diabetic')

# Labels + title
plt.xlabel('NoDocbcCost')
plt.ylabel('Frequency')
plt.title('Frequency of NoDocbcCost for Diabetes_012')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of no-doctor-cost being true and false wrt diabetes categories
docCost0_count = diabetes_0['NoDocbcCost'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = np.arange(2)
plt.bar(['false','true'], docCost0_count, width = 0.2, color='slateblue', label='non diabetic')

# Labels + title
plt.xlabel('NoDocbcCost')
plt.ylabel('Frequency')
plt.title('Frequency of NoDocbcCost for Non Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of no-doctor-cost being true and false wrt diabetes categories
docCost1_count = diabetes_1['NoDocbcCost'].value_counts().sort_index()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = np.arange(2)
plt.bar(['false','true'], docCost1_count, width = 0.2, color='firebrick', label='pre-diabetic')

# Labels + title
plt.xlabel('NoDocbcCost')
plt.ylabel('Frequency')
plt.title('Frequency of NoDocbcCost for Pre-Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
# Count occurrences of no-doctor-cost being true and false wrt diabetes categories
docCost2_count = diabetes_2['NoDocbcCost'].value_counts()

# Size of figure
plt.figure(figsize=(8, 6.5))

# Plotting the bars
x = np.arange(2)
plt.bar(['false','true'], docCost2_count, width = 0.2, color='seagreen', label='diabetic')

# Labels + title
plt.xlabel('NoDocbcCost')
plt.ylabel('Frequency')
plt.title('Frequency of NoDocbcCost for Diabetic')
# Set values on x-axis horizontal
plt.xticks(rotation=0)
# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()
